# %% [markdown]
# # [1] Numpy: ndarray 기초

# %% [markdown]
# ### [실습] 다양한 방법으로 배열 생성
#
#
# NumPy를 사용하여 다음과 같은 배열을 생성해 보세요.
#
# 1. 크기가 4x3인 모든 값이 0인 배열
# 2. 크기가 3x3인 모든 값이 1인 배열
# 3. 0에서 20까지 5씩 증가하는 값으로 구성된 배열
# 4. 0과 1 사이의 4개의 등간격 값을 가진 배열
# 5. *크기가 2x2인 정규 분포로 구성된 배열*

# %%
import numpy as np

# Numpy:ndarray 기초

# NumPy를 사용하여 다음과 같은 배열을 생성해 보세요.

# 1. 크기가 4x3인 모든 값이 0인 배열
arr = np.zeros((4,3))
print("문제 1번 : \n", arr)
print()

# 2. 크기가 3x3인 모든 값이 1인 배열
arr1 = np.ones((3,3))
print("문제 2번 : \n", arr1)
print()

# 3. 0에서 20까지 5씩 증가하는 값으로 구성된 배열
arr2 = np.arange(0, 21, 5)
print("문제 3번 : \n", arr2)
print()

# 4. 0과 1 사이의 4개의 등간격 값을 가진 배열
arr3 = np.linspace(0, 1, 4)
print("문제 4번 : \n", arr3)
print()

# 5. *크기가 2x2인 정규 분포로 구성된 배열*
arr4 = np.random.randn(2, 2)
print("문제 5번 : \n", arr4)
print()
